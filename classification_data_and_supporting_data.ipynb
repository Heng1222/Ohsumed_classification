# %% [markdown]
# <a href="https://colab.research.google.com/github/Heng1222/Ohsumed_classification/blob/main/classification_data_and_supporting_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 安裝 OpenXLab SDK
# !pip install -U openxlab -q

# 2. 設定環境變數 (請填入你真實的 AK 與 SK)
import os
os.environ['OPENXLAB_AK'] = "kbnq6p0dyyybq3np4jg5"
os.environ['OPENXLAB_SK'] = "ebl786dekwpmr4avd1xxxrbdlyxlxdyvn20rzoqm"

# --- 注意：接下來的指令就不需要再跑 !openxlab login 了 ---

# 3. 查看數據集信息
# !openxlab dataset info --dataset-repo OpenDataLab/Ohsumed

# 4. 下載整個數據集 (或是下載特定檔案)
# !openxlab dataset get --dataset-repo OpenDataLab/Ohsumed
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.5/314.5 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 19.1 MB/s eta 0:00:00
# ...

# %%
# 設定您預期下載的檔案路徑
file_path = '/content/OpenDataLab___Ohsumed'

if os.path.exists(file_path):
    file_size = os.path.getsize(file_path)
    if file_size > 0:
        print(f"✅ 下載成功！")
        print(f"檔案路徑: {file_path}")
        print(f"檔案大小: {file_size / 1024:.2f} KB")
    else:
        print(f"⚠️ 檔案存在，但大小為 0，可能下載不完全。")
else:
    print(f"❌ 找不到檔案：{file_path}，請檢查下載指令是否執行成功。")
# Out:
# ✅ 下載成功！
# 檔案路徑: /content/OpenDataLab___Ohsumed
# 檔案大小: 4.00 KB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# 1. 設定雲端硬碟中的儲存路徑 (你可以修改 'MyData/Ohsumed' 為你喜歡的名字)
destination_path = '/content/drive/MyDrive/Training_Data/Ohsumed_Original'

# 2. 如果資料夾不存在則建立它
if not os.path.exists(destination_path):
    os.makedirs(destination_path)
    print(f"✅ 已在雲端硬碟建立資料夾：{destination_path}")

# 3. 將 Colab 本地的檔案複製到雲端硬碟
# 我們複製整個 OpenDataLab___Ohsumed 資料夾
source_path = '/content/OpenDataLab___Ohsumed'

print("正在複製檔案中，請稍候...")
# 使用 cp 指令通常比 shutil 快，適合大檔案
# !cp -r "{source_path}"/* "{destination_path}"

print(f"🎉 成功！資料集已儲存至雲端硬碟：{destination_path}")
# Out:
# 正在複製檔案中，請稍候...
# 🎉 成功！資料集已儲存至雲端硬碟：/content/drive/MyDrive/Training_Data/Ohsumed_Original

# %%
# 1. 建立下載資料夾 (選擇性)
os.makedirs('/content/mesh_data', exist_ok=True)
# %cd /content/mesh_data

# 2. 開始下載最完整的 MeSH 資料集
# 下載 desc (Descriptor Records) - .gz 格式
# !wget https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/desc2025.gz

# 下載 supp (Supplementary Concept Records) - .gz 格式
# !wget https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/supp2025.gz

# 下載 pa (Pharmacological Action Records) - .xml 格式
# !wget https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/pa2025.xml

# 下載 qual (Qualifier Records) - .xml 格式
# !wget https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/qual2025.xml

# 3. 確認下載結果
# !ls -lh
# Out:
# /content/mesh_data
# --2025-12-31 07:32:19--  https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/desc2025.gz
# Resolving nlmpubs.nlm.nih.gov (nlmpubs.nlm.nih.gov)... 130.14.173.134
# Connecting to nlmpubs.nlm.nih.gov (nlmpubs.nlm.nih.gov)|130.14.173.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16840289 (16M)
# Saving to: ‘desc2025.gz’
#
# desc2025.gz         100%[===================>]  16.06M  49.1MB/s    in 0.3s
#
# 2025-12-31 07:32:19 (49.1 MB/s) - ‘desc2025.gz’ saved [16840289/16840289]
#
# --2025-12-31 07:32:20--  https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/supp2025.gz
# Resolving nlmpubs.nlm.nih.gov (nlmpubs.nlm.nih.gov)... 130.14.173.134
# Connecting to nlmpubs.nlm.nih.gov (nlmpubs.nlm.nih.gov)|130.14.173.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47283949 (45M)
# Saving to: ‘supp2025.gz’
#
# supp2025.gz         100%[===================>]  45.09M  78.9MB/s    in 0.6s
#
# ...

# %%
# 設定您預期下載的檔案路徑
file_path = '/content/mesh_data'

if os.path.exists(file_path):
    file_size = os.path.getsize(file_path)
    if file_size > 0:
        print(f"✅ 下載成功！")
        print(f"檔案路徑: {file_path}")
        print(f"檔案大小: {file_size / 1024:.2f} KB")
    else:
        print(f"⚠️ 檔案存在，但大小為 0，可能下載不完全。")
else:
    print(f"❌ 找不到檔案：{file_path}，請檢查下載指令是否執行成功。")
# Out:
# ✅ 下載成功！
# 檔案路徑: /content/mesh_data
# 檔案大小: 4.00 KB

# %%
import shutil

# 1. 設定雲端硬碟中的儲存路徑 (你可以修改 'MyData/Ohsumed' 為你喜歡的名字)
destination_path = '/content/drive/MyDrive/Supporting_Data/Mesh'

# 2. 如果資料夾不存在則建立它
if not os.path.exists(destination_path):
    os.makedirs(destination_path)
    print(f"✅ 已在雲端硬碟建立資料夾：{destination_path}")

# 3. 將 Colab 本地的檔案複製到雲端硬碟
# 我們複製整個 OpenDataLab___Ohsumed 資料夾
source_path = '/content/mesh_data'

print("正在複製檔案中，請稍候...")
# 使用 cp 指令通常比 shutil 快，適合大檔案
# !cp -r "{source_path}"/* "{destination_path}"

print(f"🎉 成功！資料集已儲存至雲端硬碟：{destination_path}")
# Out:
# 正在複製檔案中，請稍候...
# 🎉 成功！資料集已儲存至雲端硬碟：/content/drive/MyDrive/Supporting_Data/Mesh
